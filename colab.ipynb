# %% [markdown]
# # Lorenz-1960 PINN on Colab
# Runtime > Change runtime type > T4 GPU, then run all.

# %%
BRANCH = 'codex/causal-1536pt'
# !git clone --branch $BRANCH --single-branch https://github.com/ihmorol/lorenz1960-pinn.git
# %cd lorenz1960-pinn
# !pip install -q -r requirements.txt

# %%
import torch; print(torch.__version__, torch.cuda.is_available())

# %%
# !python run_causal.py

# %%
# !zip -qr runs.zip runs && ls -la runs.zip
from google.colab import files; files.download('runs.zip')
